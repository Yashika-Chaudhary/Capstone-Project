# %%
#importing requires libraries
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/home/yashika/finaldata.csv')
df
# Out:
#               State/UT  Year  population(total)      Rural     Urban  \
# 0         A& N ISLANDS  2001             356152     239954    116198
# 1       ANDHRA PRADESH  2001           76210007   55401067  20808940
# 2    ARUNACHAL PRADESH  2001            1097968     870087    227881
# 3                ASSAM  2001           26655528   23216288   3439240
# 4                BIHAR  2001           82998509   74316709   8681800
# ..                 ...   ...                ...        ...       ...
# 415         TAMIL NADU  2012           72867204   40524361  32342843
# 416            TRIPURA  2012            3717661    3088869    628792
# 417      UTTAR PRADESH  2012          202226609  159783555  42443054
# 418        UTTARAKHAND  2012           10260421    7670906   2589515
# 419        WEST BENGAL  2012           92575564   66749935  25825629
#
#          Tot_M     Tot_F        P_LIT       M_LIT     F_LIT  ...  \
# 0       192972    163180     253135.0    146831.0    106304  ...
# 1     38527413  37682594   39934323.0  23444788.0  16489535  ...
# 2       579941    518027     484785.0    303281.0    181504  ...
# 3     13777037  12878491   14015354.0   8188697.0   5826657  ...
# 4     43243795  39754714   31109577.0  20644376.0  10465201  ...
# ..         ...       ...          ...         ...       ...  ...
# 415   36680044  36477172   53274562.0  28573260.0  24701302  ...
# 416    1889371   1826534    2897340.0   1538903.0   1355550  ...
# 417  107092522  96666476  118889202.0  70418482.0  48470720  ...
# 418    5240528   5136562    7100774.0   3971891.0   3128883  ...
# 419   47417544  45045160   63274096.0  34529005.0  28745091  ...
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                              0                            0
# 1                                              7                         7400
# 2                                              0                            0
# 3                                              0                         2010
# 4                                             83                         2406
# ..                                           ...                          ...
# 415                                            0                        15499
# 416                                            0                           10
# 417                                            0                        14406
# 418                                            0                          670
# 419                                           12                         4385
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES  Total Crimes  tot_crimes_sc  \
# 0                 323               658          1386              0
# 1               34344            130089        278982           2933
# 2                 618              2342          5243              0
# 3                9315             36877         81418              6
# 4               36667             88432        189612           1303
# ..                ...               ...           ...            ...
# 415            124176            200474        415626           1647
# 416              1742              6264         13461             76
# 417             68538            198093        444403           6202
# 418              2118              8882         20122             33
# 419             64482            161427        353008             85
#
#      total crime against women  Total crimes against STs  \
# 0                         34.0                       1.0
# 1                      13669.0                     512.0
# 2                        180.0                      72.0
# 3                       4048.0                       0.0
# 4                       4489.0                      83.0
# ..                         ...                       ...
# 415                     6381.0                      27.0
# 416                     1559.0                      29.0
# 417                    23033.0                      44.0
# 418                     1055.0                       3.0
# 419                    30585.0                      91.0
#
#      Total crime against children  Crime Rate
# 0                             0.0  184.752578
# 1                           270.0  170.698055
# 2                             0.0  213.303120
# 3                            18.0  138.346537
# 4                            83.0  106.546492
# ..                            ...         ...
# 415                        1036.0  275.122399
# 416                          20.0  168.493039
# 417                        6033.0   97.955952
# 418                         122.0   86.565649
# 419                        1706.0  174.373229
#
# [420 rows x 48 columns]

# %% [markdown]
# Data have been collected from the different websites manually for the population,area of each state and literacy rate of each state .The data was available for the year #2001 and #2012 for population, area and literacy rate of each state. So, necassary calculations and assumptions were made in order to achive the data for the year #2002 to #2010 & year #2012..Several websites were used in order to fetch the data for the same. Some of them are:-
#
# https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area
# https://en.wikipedia.org/wiki/List_of_Indian_states_and_union_territories_by_literacy_rate
# https://socialjustice.gov.in/common/76669
# http://cyberjournalist.org.in/census/cenindia.html
# https://www.indiastat.com/specimen-tables/geographical-data
# https://www.wbhealth.gov.in/other_files/2007/14_5.html
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population
# https://www.prb.org/wp-content/uploads/2011/04/india-population-2001-2011.pdf
# https://censusindia.gov.in/nada/index.php/catalog/20030
# https://scikit-learn.org/stable/user_guide.html
# https://github.com/
# https://www.kaggle.com/
# https://medium.com/
# https://towardsdatascience.com/
# https://www.analyticsvidhya.com/
# https://www.geeksforgeeks.org/
# https://www.latestlaws.com/wp-content/uploads/2018/07/National-Crime-Record-Bureau-Report-NCRB-2012.pdf
